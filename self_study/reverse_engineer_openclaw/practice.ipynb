# %%
import asyncio

async def test():
    await asyncio.sleep(5)
    print(234)

await test()
print(123)
# Out:
# 234
# 123
# C:\Users\dapen\AppData\Local\Temp\ipykernel_30692\3577417487.py:4: RuntimeWarning: coroutine 'sleep' was never awaited
#   asyncio.sleep(5)
# ...
